# %%
dir <- "~/work/courses/stat380/weeks/week-5"
library(renv)
setwd(dir)
renv::activate(dir)

# %%
library(ISLR2)
library(ggplot2)
library(tidyr)
library(dplyr)

# %%
ggplot(iris) +
    geom_point(aes(x=Sepal.Length, y=Petal.Width, color=Species)) +
    geom_smooth(aes(x=Sepal.Length, y=Petal.Width, color=Species)) +
    facet_wrap(~{Species}, nrow=2, ncol=2)
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %% [markdown]
# This is some text which I am inserting here, and which I am going to explicitly consider when I talk about it in class
